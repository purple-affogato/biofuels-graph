# %%
# %pip install pandas matplotlib

import pandas as pd
import matplotlib.pyplot as plt
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
df = pd.read_csv('u-s-domestic-corn-use.csv')
df
# Out:
#     Year                               Column2  \
# 0   2000                 Feed and residual use
# 1   2000                  Alcohol for fuel use
# 2   2000  Other food, seed, and industrial use
# 3   2001                 Feed and residual use
# 4   2001                  Alcohol for fuel use
# ..   ...                                   ...
# 64  2021                  Alcohol for fuel use
# 65  2021  Other food, seed, and industrial use
# 66  2022                 Feed and residual use
# 67  2022                  Alcohol for fuel use
# 68  2022  Other food, seed, and industrial use
#
#     Total Corn consumed for fuel in billions of bushels  \
# 0                                         5818.902000
# 1                                          629.827200
# 2                                         1350.238740
# 3                                         5845.195000
# 4                                          707.238461
# ..                                                ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 69 entries, 0 to 68
# Data columns (total 5 columns):
#  #   Column                                                   Non-Null Count  Dtype
# ---  ------                                                   --------------  -----
#  0   Year                                                     69 non-null     int64
#  1   Column2                                                  69 non-null     object
#  2   Total Corn consumed for fuel in billions of bushels      69 non-null     float64
#  3   Total Corn consumed dosmetically in billions of bushels  23 non-null     float64
#  4   Percentage of corn consumed domestically used for fuel   63 non-null     object
# dtypes: float64(2), int64(1), object(2)
# memory usage: 2.8+ KB

# %%
for i in range(0, 69, 3):
    df.iloc[i+1, 3] = df.iloc[i, 3]
    df.iloc[i+2, 3] = df.iloc[i, 3]

# %%
df
# Out:
#     Year                               Column2  \
# 0   2000                 Feed and residual use
# 1   2000                  Alcohol for fuel use
# 2   2000  Other food, seed, and industrial use
# 3   2001                 Feed and residual use
# 4   2001                  Alcohol for fuel use
# ..   ...                                   ...
# 64  2021                  Alcohol for fuel use
# 65  2021  Other food, seed, and industrial use
# 66  2022                 Feed and residual use
# 67  2022                  Alcohol for fuel use
# 68  2022  Other food, seed, and industrial use
#
#     Total Corn consumed for fuel in billions of bushels  \
# 0                                         5818.902000
# 1                                          629.827200
# 2                                         1350.238740
# 3                                         5845.195000
# 4                                          707.238461
# ..                                                ...
# ...

# %%
df.drop(axis=0, index=range(0, 69, 3), inplace=True)

# %%
df.drop(axis=0, index=range(2, 69, 3), inplace=True)

# %%
df.index = range(23)

# %%
df
# Out:
#     Year               Column2  \
# 0   2000  Alcohol for fuel use
# 1   2001  Alcohol for fuel use
# 2   2002  Alcohol for fuel use
# 3   2003  Alcohol for fuel use
# 4   2004  Alcohol for fuel use
# 5   2005  Alcohol for fuel use
# 6   2006  Alcohol for fuel use
# 7   2007  Alcohol for fuel use
# 8   2008  Alcohol for fuel use
# 9   2009  Alcohol for fuel use
# 10  2010  Alcohol for fuel use
# 11  2011  Alcohol for fuel use
# 12  2012  Alcohol for fuel use
# 13  2013  Alcohol for fuel use
# 14  2014  Alcohol for fuel use
# 15  2015  Alcohol for fuel use
# 16  2016  Alcohol for fuel use
# 17  2017  Alcohol for fuel use
# 18  2018  Alcohol for fuel use
# 19  2019  Alcohol for fuel use
# 20  2020  Alcohol for fuel use
# 21  2021  Alcohol for fuel use
# 22  2022  Alcohol for fuel use
#
#     Total Corn consumed for fuel in billions of bushels  \
# 0                                          629.827200
# 1                                          707.238461
# ...

# %%
for i in range(23):
    df.iloc[i,4] = round(df.iloc[i,2] / df.iloc[i,3] * 100, 2)

# %%
df
# Out:
#     Year               Column2  \
# 0   2000  Alcohol for fuel use
# 1   2001  Alcohol for fuel use
# 2   2002  Alcohol for fuel use
# 3   2003  Alcohol for fuel use
# 4   2004  Alcohol for fuel use
# 5   2005  Alcohol for fuel use
# 6   2006  Alcohol for fuel use
# 7   2007  Alcohol for fuel use
# 8   2008  Alcohol for fuel use
# 9   2009  Alcohol for fuel use
# 10  2010  Alcohol for fuel use
# 11  2011  Alcohol for fuel use
# 12  2012  Alcohol for fuel use
# 13  2013  Alcohol for fuel use
# 14  2014  Alcohol for fuel use
# 15  2015  Alcohol for fuel use
# 16  2016  Alcohol for fuel use
# 17  2017  Alcohol for fuel use
# 18  2018  Alcohol for fuel use
# 19  2019  Alcohol for fuel use
# 20  2020  Alcohol for fuel use
# 21  2021  Alcohol for fuel use
# 22  2022  Alcohol for fuel use
#
#     Total Corn consumed for fuel in billions of bushels  \
# 0                                          629.827200
# 1                                          707.238461
# ...

# %%
plt.title('Percentage of corn used domestically used for fuel per year from 2000 to 2022')
plt.xlabel('Year')
plt.ylabel('Percentage of corn used')
plt.plot(df['Year'], df['Percentage of corn consumed domestically used for fuel'])
